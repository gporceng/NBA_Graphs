# %%
#pip install nba_api

# %%
#Lets grab some player data

# %%
from nba_api.stats.endpoints import playercareerstats

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
#career.get_data_frames()[0]

# json
#career.get_json()

# dictionary
#career.get_dict()

# %%
#Jokic players stats
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
# 5     203999   2020-21        00  1610612743               DEN        26.0
# 6     203999   2021-22        00  1610612743               DEN        27.0
# 7     203999   2022-23        00  1610612743               DEN        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0  80  55  1733.0  307  ...   0.811   181   379   560  189   79   50  104
# 1  73  59  2038.0  494  ...   0.825   212   506   718  359   61   55  171
# 2  75  73  2443.0  504  ...   0.850   195   608   803  458   90   61  210
# 3  80  80  2504.0  616  ...   0.821   228   637   865  580  108   55  248
# 4  73  73  2335.0  565  ...   0.817   166   545   711  512   85   44  226
# 5  72  72  2488.0  732  ...   0.868   205   575   780  599   95   48  222
# 6  74  74  2476.0  764  ...   0.810   206   813  1019  584  109   63  281
# 7  55  55  1846.0  516  ...   0.822   128   515   643  551   70   36  196
#
#     PF   PTS
# 0  208   796
# 1  214  1221
# 2  212  1385
# 3  228  1604
# 4  222  1456
# 5  192  1898
# 6  191  2004
# 7  142  1354
#
# [8 rows x 27 columns]

# %%
career.get_data_frames()[1]
# Out:
#    PLAYER_ID LEAGUE_ID  Team_ID   GP   GS      MIN   FGM   FGA    FG_PCT  \
# 0     203999        00        0  582  541  17861.0  4498  8160  0.551225
#
#    FG3M  ...    FT_PCT  OREB  DREB   REB   AST  STL  BLK   TOV    PF    PTS
# 0   581  ...  0.828881  1521  4578  6099  3832  697  412  1658  1609  11718
#
# [1 rows x 24 columns]

# %%
df = career.get_data_frames()
type(df[1])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0]
# scatter plot
df[0].plot(kind = 'line',x = 'SEASON_ID',y = 'PTS',color = 'red',title='Points/Year Nikola Jokic')
# Out:
# <AxesSubplot:title={'center':'Points/Year Nikola Jokic'}, xlabel='SEASON_ID'>

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()

# plot the first y-value
df[0].plot(kind='line', x='SEASON_ID', y='PTS', color='red', ax=ax1)
ax1.set_xlabel('SEASON_ID')
ax1.set_ylabel('Points')

# create a second y-axis and plot the second y-value
ax2 = ax1.twinx()
df[0].plot(kind='line', x='SEASON_ID', y='REB', color='blue', ax=ax2)
ax2.set_ylabel('Rebounds')

plt.title('Points/Year Nikola Jokic')
plt.show()

# %%
import matplotlib.pyplot as plt

# create a larger figure size
fig, ax1 = plt.subplots(figsize=(8, 5))

# plot the first y-value
df[0].plot(kind='line', x='SEASON_ID', y='PTS', color='red', ax=ax1)
ax1.set_xlabel('Season', fontsize=12)
ax1.set_ylabel('Points', fontsize=12)

# create a second y-axis and plot the second y-value
ax2 = ax1.twinx()
df[0].plot(kind='line', x='SEASON_ID', y='REB', color='blue', ax=ax2)
ax2.set_ylabel('Rebounds', fontsize=12)

plt.title('Points/Year Nikola Jokic', fontsize=14)
plt.show()

# %%
jokic = df[0]

# %%
jokic['PTS']/jokic['GP']
# Out:
# 0     9.950000
# 1    16.726027
# 2    18.466667
# 3    20.050000
# 4    19.945205
# 5    26.361111
# 6    27.081081
# 7    24.618182
# dtype: float64

# %%
#Lets Add a new player to the mix

# %%
def plotPlayerStats(id):
    career = playercareerstats.PlayerCareerStats(player_id=id)
    return career.get_data_frames()[0]

# %%
embiid = plotPlayerStats(203954)
embiid
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203954   2016-17        00  1610612755               PHI        23.0
# 1     203954   2017-18        00  1610612755               PHI        24.0
# 2     203954   2018-19        00  1610612755               PHI        25.0
# 3     203954   2019-20        00  1610612755               PHI        26.0
# 4     203954   2020-21        00  1610612755               PHI        27.0
# 5     203954   2021-22        00  1610612755               PHI        28.0
# 6     203954   2022-23        00  1610612755               PHI        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  31  31   786.0  200  ...   0.783    61   182  243   66   27   76  117  112
# 1  63  63  1912.0  510  ...   0.769   143   547  690  199   40  111  234  209
# 2  64  64  2154.0  580  ...   0.804   160   711  871  234   46  122  226  211
# 3  51  51  1506.0  382  ...   0.807   141   452  593  152   45   65  159  174
# 4  51  51  1585.0  461  ...   0.859   113   426  539  145   50   69  159  123
# 5  68  68  2296.0  666  ...   0.814   146   650  796  284   77   99  214  181
# 6  48  48  1683.0  525  ...   0.860    86   414  500  196   53   78  170  153
#
#     PTS
# 0   627
# 1  1445
# 2  1761
# 3  1172
# 4  1451
# 5  2079
# 6  1584
#
# [7 rows x 27 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def plot_stats(df, stat_list):
    """Plot multiple stats over time for a given DataFrame."""
    # create a new DataFrame with only the specified columns
    stat_df = df[stat_list + ['SEASON_ID']]
    # set the index to the season ID column
    stat_df.set_index('SEASON_ID', inplace=True)

    # plot each stat on a separate axis
    fig, ax = plt.subplots(figsize=(20, 10))
    for i, stat in enumerate(stat_list):
        # plot the stat on the current axis
        ax.plot(stat_df.index, stat_df[stat], label=stat, color=plt.cm.get_cmap('Set1')(i/len(stat_list)))
        ax.tick_params(axis='y', labelcolor=plt.cm.get_cmap('Set1')(i/len(stat_list)))
        
    # set axis labels and title
    ax.set_xlabel('Season', fontsize=20)
    ax.set_ylabel('Stats', fontsize=20)
    ax.set_title('Stats over time', fontsize=24)
    
    # set the y axis limits and ticks
    ax.set_ylim([0, df[stat_list].max().max()])
    y_ticks = np.arange(0, df[stat_list].max().max(), df[stat_list].max().max() / 5)
    ax.set_yticks(y_ticks)
    ax.tick_params(axis='both', labelsize=16)
    
    # create a legend for the plot
    lines, labels = ax.get_legend_handles_labels()
    ax.legend(lines, labels, loc='upper left', fontsize=16)

    # adjust the layout of the plot
    plt.subplots_adjust(left=0.15, bottom=0.15)

    # rotate x-axis labels
    plt.xticks(rotation=90)

    # show the plot
    plt.show()

# %%
plot_stats(jokic,['PTS','REB'])

# %%
plot_stats(embiid,['PTS','REB','PF'])

# %%
#From docs

# %%
from nba_api.stats.static import players
# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_players[:5]
# Out:
# Number of players fetched: 4831
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False}]

# %%
big_fundamental = [player for player in nba_players
                   if player['full_name'] == 'Tim Duncan'][0]
big_fundamental
# Out:
# {'id': 1495,
#  'full_name': 'Tim Duncan',
#  'first_name': 'Tim',
#  'last_name': 'Duncan',
#  'is_active': False}

# %%
def getPlayerID(Name):
    nba_players = players.get_players()
    ID = [player for player in nba_players
        if player['full_name'] == Name][0]
    return ID['id']

# %%
timduncan = getPlayerID("Tim Duncan")

# %%
timduncan
# Out:
# 1495

# %%
timd = playercareerstats.PlayerCareerStats(player_id=timduncan)

# %%
plotPlayerStats(timduncan)
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        1495   1997-98        00  1610612759               SAS        22.0
# 1        1495   1998-99        00  1610612759               SAS        23.0
# 2        1495   1999-00        00  1610612759               SAS        24.0
# 3        1495   2000-01        00  1610612759               SAS        25.0
# 4        1495   2001-02        00  1610612759               SAS        26.0
# 5        1495   2002-03        00  1610612759               SAS        27.0
# 6        1495   2003-04        00  1610612759               SAS        28.0
# 7        1495   2004-05        00  1610612759               SAS        29.0
# 8        1495   2005-06        00  1610612759               SAS        30.0
# 9        1495   2006-07        00  1610612759               SAS        31.0
# 10       1495   2007-08        00  1610612759               SAS        32.0
# 11       1495   2008-09        00  1610612759               SAS        33.0
# 12       1495   2009-10        00  1610612759               SAS        34.0
# 13       1495   2010-11        00  1610612759               SAS        35.0
# 14       1495   2011-12        00  1610612759               SAS        36.0
# 15       1495   2012-13        00  1610612759               SAS        37.0
# 16       1495   2013-14        00  1610612759               SAS        38.0
# 17       1495   2014-15        00  1610612759               SAS        39.0
# 18       1495   2015-16        00  1610612759               SAS        40.0
#
#     GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0   82  82  3204.0  706  ...   0.662   274   703   977  224   55  206  279
# 1   50  50  1963.0  418  ...   0.690   159   412   571  121   45  126  146
# 2   74  74  2875.0  628  ...   0.761   262   656   918  234   66  165  242
# 3   82  82  3174.0  702  ...   0.618   259   738   997  245   70  192  242
# 4   82  82  3329.0  764  ...   0.799   268   774  1042  307   61  203  263
# 5   81  81  3181.0  714  ...   0.710   259   784  1043  316   55  237  248
# 6   69  68  2527.0  592  ...   0.599   227   632   859  213   62  185  183
# 7   66  66  2203.0  517  ...   0.670   202   530   732  179   45  174  127
# 8   80  80  2784.0  574  ...   0.629   231   650   881  253   70  162  198
# 9   80  80  2726.0  618  ...   0.637   213   633   846  273   66  190  224
# 10  78  78  2651.0  585  ...   0.730   237   644   881  218   56  152  178
# 11  75  75  2523.0  558  ...   0.692   201   599   800  264   38  126  165
# 12  78  77  2438.0  561  ...   0.725   221   567   788  246   45  117  140
# 13  76  76  2156.0  419  ...   0.716   169   509   678  203   50  146  122
# 14  58  58  1634.0  361  ...   0.695   110   410   520  132   38   88   97
# 15  69  69  2078.0  490  ...   0.817   124   562   686  184   50  183  147
# 16  74  74  2158.0  444  ...   0.731   158   563   721  220   43  139  159
# 17  77  77  2227.0  419  ...   0.740   170   534   704  230   63  151  131
# 18  61  60  1536.0  215  ...   0.702   115   332   447  163   47   78   90
#
#      PF   PTS
# 0   254  1731
# 1   147  1084
# 2   210  1716
# 3   247  1820
# 4   217  2089
# 5   231  1884
# 6   164  1538
# 7   144  1342
# 8   219  1485
# 9   203  1599
# 10  185  1508
# 11  173  1450
# 12  152  1395
# 13  119  1022
# 14   98   895
# 15  117  1227
# 16  134  1119
# 17  165  1070
# 18  125   522
#
# [19 rows x 27 columns]

# %%
goat = plotPlayerStats(getPlayerID("LaMelo Ball"))

# %%
plot_stats(goat,['GP'])

# %%
#functions
"""
getPlayerID("LaMelo Ball")
plotPlayerStats(lamelo)
plot_stats(goat,['GP'])

"""

# %%
def plotPts(player):
    plot_stats(plotPlayerStats(getPlayerID(player)),['PTS'])

# %%
plotPts("Carmelo Anthony")

# %%
def plotCarStats(player):
    plotPlayerStats(getPlayerID(player))

# %%
cm = getPlayerID("Carmelo Anthony")

# %%
carm = plotPlayerStats(cm)

carm_tot = carm[carm['TEAM_ABBREVIATION'] == 'TOT']

#carm_tot

c = carm.duplicated(subset=['SEASON_ID'], keep=False)
out = carm[~c]
out_tot = pd.concat([carm_tot, out])
out_tot.sort_values(by=['SEASON_ID'])
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2546   2003-04        00  1610612743               DEN        20.0
# 1        2546   2004-05        00  1610612743               DEN        21.0
# 2        2546   2005-06        00  1610612743               DEN        22.0
# 3        2546   2006-07        00  1610612743               DEN        23.0
# 4        2546   2007-08        00  1610612743               DEN        24.0
# 5        2546   2008-09        00  1610612743               DEN        25.0
# 6        2546   2009-10        00  1610612743               DEN        26.0
# 9        2546   2010-11        00           0               TOT        27.0
# 10       2546   2011-12        00  1610612752               NYK        28.0
# 11       2546   2012-13        00  1610612752               NYK        29.0
# 12       2546   2013-14        00  1610612752               NYK        30.0
# 13       2546   2014-15        00  1610612752               NYK        31.0
# 14       2546   2015-16        00  1610612752               NYK        32.0
# 15       2546   2016-17        00  1610612752               NYK        33.0
# 16       2546   2017-18        00  1610612760               OKC        34.0
# 17       2546   2018-19        00  1610612745               HOU        35.0
# 18       2546   2019-20        00  1610612757               POR        36.0
# 19       2546   2020-21        00  1610612757               POR        37.0
# 20       2546   2021-22        00  1610612747               LAL        38.0
#
#     GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0   82  82  2994.0  624  ...   0.777   183   315  498  227   97   41  247
# 1   75  75  2608.0  530  ...   0.796   141   285  426  194   68   30  224
# 2   80  80  2941.0  756  ...   0.808   122   272  394  216   88   42  218
# 3   65  65  2486.0  691  ...   0.808   143   248  391  249   77   23  234
# 4   77  77  2806.0  728  ...   0.786   178   393  571  259   98   39  253
# 5   66  66  2277.0  535  ...   0.793   106   344  450  222   75   24  199
# 6   69  69  2634.0  688  ...   0.830   152   302  454  222   88   30  209
# 9   77  77  2751.0  684  ...   0.838   118   445  563  221   68   46  206
# 10  55  55  1876.0  441  ...   0.804    88   256  344  200   62   24  144
# 11  67  67  2482.0  669  ...   0.830   134   326  460  171   52   32  175
# 12  77  77  2982.0  743  ...   0.848   145   477  622  242   95   51  198
# 13  40  40  1428.0  358  ...   0.797    72   192  264  122   40   17   89
# 14  72  72  2530.0  567  ...   0.829    98   458  556  299   62   38  176
# 15  74  74  2538.0  602  ...   0.833    62   376  438  213   60   34  153
# 16  78  78  2501.0  472  ...   0.767    67   386  453  103   47   49   99
# 17  10   2   294.0   49  ...   0.682     9    45   54    5    4    7    8
# 18  58  58  1902.0  336  ...   0.845    71   297  368   85   49   27  100
# 19  69   3  1690.0  327  ...   0.890    32   182  214  104   46   38   61
# 20  69   3  1793.0  319  ...   0.830    62   226  288   68   47   52   59
#
#      PF   PTS
# 0   225  1725
# 1   229  1558
# 2   229  2122
# 3   203  1881
# 4   253  1978
# 5   195  1504
# 6   225  1943
# 9   224  1970
# 10  156  1245
# 11  205  1920
# 12  224  2112
# 13   87   966
# 14  180  1573
# 15  198  1659
# 16  197  1261
# 17   32   134
# 18  171   895
# 19  144   924
# 20  166   919
#
# [19 rows x 27 columns]

# %%
#Bill Russell
six = getPlayerID("Bill Russell")
six = plotPlayerStats(six)
six_drop = six.drop_duplicates()
six_tot = six_drop[six_drop['TEAM_ABBREVIATION'] == 'TOT']
six_dup = six_drop.duplicated(subset=['SEASON_ID'], keep=False)
out = six[~six_dup]
out_tot = pd.concat([out,six_tot])

#out_tot.sort_values(by=['SEASON_ID'])
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0       78049   1956-57        00  1610612738               BOS        23.0
# 1       78049   1957-58        00  1610612738               BOS        24.0
# 2       78049   1958-59        00  1610612738               BOS        25.0
# 3       78049   1959-60        00  1610612738               BOS        26.0
# 4       78049   1960-61        00  1610612738               BOS        27.0
# 5       78049   1961-62        00  1610612738               BOS        28.0
# 6       78049   1962-63        00  1610612738               BOS        29.0
# 7       78049   1963-64        00  1610612738               BOS        30.0
# 8       78049   1964-65        00  1610612738               BOS        31.0
# 9       78049   1965-66        00  1610612738               BOS        32.0
# 10      78049   1966-67        00  1610612738               BOS        33.0
# 11      78049   1967-68        00  1610612738               BOS        34.0
# 12      78049   1968-69        00  1610612738               BOS        35.0
#
#     GP    GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST   STL   BLK  \
# 0   48  None  1695.0  277  ...   0.492  None  None   943   88  None  None
# 1   69  None  2640.0  456  ...   0.519  None  None  1564  202  None  None
# 2   70  None  2979.0  456  ...   0.598  None  None  1612  222  None  None
# 3   74  None  3146.0  555  ...   0.612  None  None  1778  277  None  None
# 4   78  None  3458.0  532  ...   0.550  None  None  1868  268  None  None
# 5   76  None  3433.0  575  ...   0.595  None  None  1790  341  None  None
# 6   78  None  3500.0  511  ...   0.555  None  None  1843  348  None  None
# 7   78  None  3482.0  466  ...   0.550  None  None  1930  370  None  None
# 8   78  None  3466.0  429  ...   0.573  None  None  1878  410  None  None
# 9   78  None  3386.0  391  ...   0.551  None  None  1779  371  None  None
# 10  81  None  3297.0  395  ...   0.610  None  None  1700  472  None  None
# 11  78  None  2953.0  365  ...   0.537  None  None  1451  357  None  None
# 12  77  None  3291.0  279  ...   0.526  None  None  1484  374  None  None
#
#      TOV   PF   PTS
# 0   None  143   706
# 1   None  181  1142
# 2   None  161  1168
# 3   None  210  1350
# 4   None  155  1322
# 5   None  207  1436
# 6   None  189  1309
# 7   None  190  1168
# 8   None  204  1102
# 9   None  221  1005
# 10  None  258  1075
# 11  None  242   977
# 12  None  231   762
#
# [13 rows x 27 columns]

# %%
def cleanCarData(name):
    player = getPlayerID(name)
    player = plotPlayerStats(player)
    player_drop = player.drop_duplicates()
    player_tot = player_drop[player_drop['TEAM_ABBREVIATION'] == 'TOT']
    player_dup = player_drop.duplicated(subset=['SEASON_ID'], keep=False)
    out = player[~player_dup]
    out_tot = pd.concat([out,player_tot])
    return out_tot.sort_values(by=['SEASON_ID'])

# %%
pb = cleanCarData("Patrick Beverley")

# %%
def plot
